# %%
import pandas as pd

# %%
df1 = pd.read_csv('data_full.csv')

# %%
df1.head(3)
# Out:
#    BostonNamingTestEstimatedTotalScoreoutof60_int  \
# 0                                       58.851292
# 1                                       57.263975
# 2                                       56.582306
#
#    BostonNamingTestEstimatedTotalScoreoutof60_slope  \
# 0                                          0.011574
# 1                                          0.009936
# 2                                          0.007339
#
#    CategoryFluencyAnimalsRawScore_int  CategoryFluencyAnimalsRawScore_slope  \
# 0                           28.500938                             -0.066920
# 1                           30.211110                             -0.067709
# 2                           28.924394                             -0.075169
#
#    WAISRDigitSymbolTotalRaw_int  WAISRDigitSymbolTotalRaw_slope  \
# 0                     93.665138                       -0.496398
# 1                     93.658285                       -0.496647
# ...
